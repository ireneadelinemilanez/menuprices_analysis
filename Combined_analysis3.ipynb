# %%
## import library
import pandas as pd

# %%
df = pd.read_csv("combined3.csv")
df
# Out:
#       date  cpi_away_food  med_inc_house  avg_chipotle  avg_cava  \
# 0   1/1/18        275.893        77700.0         14.07     17.31
# 1   1/1/19        284.410        83260.0         14.96     18.73
# 2   1/1/20        293.944        81580.0         17.75     20.52
# 3   1/1/21        307.296        81270.0         18.90     20.97
# 4   1/1/22        330.822        79500.0         20.00     20.77
# 5   1/1/23        354.256        82690.0         20.54     20.54
# 6   1/1/24        368.743        83730.0         20.94     21.32
# 7   1/1/25        382.378        85157.0         21.13     21.71
# 8      NaN            NaN            NaN           NaN       NaN
# 9      NaN            NaN            NaN           NaN       NaN
# 10     NaN            NaN            NaN           NaN       NaN
# 11     NaN            NaN            NaN           NaN       NaN
#
#     avg_sweetgreen  Unnamed: 6
# 0            14.39         NaN
# 1            14.90         NaN
# 2            17.95         NaN
# 3            19.23         NaN
# 4            19.89         NaN
# 5            21.40         NaN
# 6            23.90         NaN
# 7            24.58         NaN
# 8              NaN         NaN
# 9              NaN         NaN
# 10             NaN         NaN
# 11             NaN         NaN

# %%
cpi_start = df["cpi_away_food"].iat[0]
cpi_start
# Out:
# np.float64(275.893)

# %%
house_start = df["med_inc_house"].iat[0]
house_start
# Out:
# np.float64(77700.0)

# %%
chipotle_start = df["avg_chipotle"].iat[0]
chipotle_start
# Out:
# np.float64(14.07)

# %%
cava_start = df["avg_cava"].iat[0]
cava_start
# Out:
# np.float64(17.31)

# %%
sweetgreen_start = df["avg_sweetgreen"].iat[0]
sweetgreen_start
# Out:
# np.float64(14.39)

# %%
df["cpi_zero_index"] = df["cpi_away_food"].apply(lambda x:round((x-cpi_start)/cpi_start*100, 2))
df
# Out:
#       date  cpi_away_food  med_inc_house  avg_chipotle  avg_cava  \
# 0   1/1/18        275.893        77700.0         14.07     17.31
# 1   1/1/19        284.410        83260.0         14.96     18.73
# 2   1/1/20        293.944        81580.0         17.75     20.52
# 3   1/1/21        307.296        81270.0         18.90     20.97
# 4   1/1/22        330.822        79500.0         20.00     20.77
# 5   1/1/23        354.256        82690.0         20.54     20.54
# 6   1/1/24        368.743        83730.0         20.94     21.32
# 7   1/1/25        382.378        85157.0         21.13     21.71
# 8      NaN            NaN            NaN           NaN       NaN
# 9      NaN            NaN            NaN           NaN       NaN
# 10     NaN            NaN            NaN           NaN       NaN
# 11     NaN            NaN            NaN           NaN       NaN
#
#     avg_sweetgreen  Unnamed: 6  cpi_zero_index
# 0            14.39         NaN            0.00
# 1            14.90         NaN            3.09
# 2            17.95         NaN            6.54
# 3            19.23         NaN           11.38
# 4            19.89         NaN           19.91
# 5            21.40         NaN           28.40
# 6            23.90         NaN           33.65
# 7            24.58         NaN           38.60
# 8              NaN         NaN             NaN
# 9              NaN         NaN             NaN
# 10             NaN         NaN             NaN
# 11             NaN         NaN             NaN

# %%
df["house_zero_index"] = df["med_inc_house"].apply(lambda x:round((x-house_start)/house_start*100, 2))
df
# Out:
#       date  cpi_away_food  med_inc_house  avg_chipotle  avg_cava  \
# 0   1/1/18        275.893        77700.0         14.07     17.31
# 1   1/1/19        284.410        83260.0         14.96     18.73
# 2   1/1/20        293.944        81580.0         17.75     20.52
# 3   1/1/21        307.296        81270.0         18.90     20.97
# 4   1/1/22        330.822        79500.0         20.00     20.77
# 5   1/1/23        354.256        82690.0         20.54     20.54
# 6   1/1/24        368.743        83730.0         20.94     21.32
# 7   1/1/25        382.378        85157.0         21.13     21.71
# 8      NaN            NaN            NaN           NaN       NaN
# 9      NaN            NaN            NaN           NaN       NaN
# 10     NaN            NaN            NaN           NaN       NaN
# 11     NaN            NaN            NaN           NaN       NaN
#
#     avg_sweetgreen  Unnamed: 6  cpi_zero_index  house_zero_index
# 0            14.39         NaN            0.00              0.00
# 1            14.90         NaN            3.09              7.16
# 2            17.95         NaN            6.54              4.99
# 3            19.23         NaN           11.38              4.59
# 4            19.89         NaN           19.91              2.32
# 5            21.40         NaN           28.40              6.42
# 6            23.90         NaN           33.65              7.76
# 7            24.58         NaN           38.60              9.60
# 8              NaN         NaN             NaN               NaN
# 9              NaN         NaN             NaN               NaN
# 10             NaN         NaN             NaN               NaN
# 11             NaN         NaN             NaN               NaN

# %%
df["chipotle_zero_index"] = df["avg_chipotle"].apply(lambda x:round((x-chipotle_start)/chipotle_start*100, 2))
df
# Out:
#       date  cpi_away_food  med_inc_house  avg_chipotle  avg_cava  \
# 0   1/1/18        275.893        77700.0         14.07     17.31
# 1   1/1/19        284.410        83260.0         14.96     18.73
# 2   1/1/20        293.944        81580.0         17.75     20.52
# 3   1/1/21        307.296        81270.0         18.90     20.97
# 4   1/1/22        330.822        79500.0         20.00     20.77
# 5   1/1/23        354.256        82690.0         20.54     20.54
# 6   1/1/24        368.743        83730.0         20.94     21.32
# 7   1/1/25        382.378        85157.0         21.13     21.71
# 8      NaN            NaN            NaN           NaN       NaN
# 9      NaN            NaN            NaN           NaN       NaN
# 10     NaN            NaN            NaN           NaN       NaN
# 11     NaN            NaN            NaN           NaN       NaN
#
#     avg_sweetgreen  Unnamed: 6  cpi_zero_index  house_zero_index  \
# 0            14.39         NaN            0.00              0.00
# 1            14.90         NaN            3.09              7.16
# 2            17.95         NaN            6.54              4.99
# 3            19.23         NaN           11.38              4.59
# 4            19.89         NaN           19.91              2.32
# 5            21.40         NaN           28.40              6.42
# 6            23.90         NaN           33.65              7.76
# 7            24.58         NaN           38.60              9.60
# 8              NaN         NaN             NaN               NaN
# 9              NaN         NaN             NaN               NaN
# 10             NaN         NaN             NaN               NaN
# 11             NaN         NaN             NaN               NaN
#
#     chipotle_zero_index
# 0                  0.00
# 1                  6.33
# 2                 26.15
# 3                 34.33
# 4                 42.15
# 5                 45.98
# 6                 48.83
# 7                 50.18
# 8                   NaN
# 9                   NaN
# 10                  NaN
# 11                  NaN

# %%
df = df.drop(columns=['Unnamed: 6'])
df
# Out:
#       date  cpi_away_food  med_inc_house  avg_chipotle  avg_cava  \
# 0   1/1/18        275.893        77700.0         14.07     17.31
# 1   1/1/19        284.410        83260.0         14.96     18.73
# 2   1/1/20        293.944        81580.0         17.75     20.52
# 3   1/1/21        307.296        81270.0         18.90     20.97
# 4   1/1/22        330.822        79500.0         20.00     20.77
# 5   1/1/23        354.256        82690.0         20.54     20.54
# 6   1/1/24        368.743        83730.0         20.94     21.32
# 7   1/1/25        382.378        85157.0         21.13     21.71
# 8      NaN            NaN            NaN           NaN       NaN
# 9      NaN            NaN            NaN           NaN       NaN
# 10     NaN            NaN            NaN           NaN       NaN
# 11     NaN            NaN            NaN           NaN       NaN
#
#     avg_sweetgreen  cpi_zero_index  house_zero_index  chipotle_zero_index
# 0            14.39            0.00              0.00                 0.00
# 1            14.90            3.09              7.16                 6.33
# 2            17.95            6.54              4.99                26.15
# 3            19.23           11.38              4.59                34.33
# 4            19.89           19.91              2.32                42.15
# 5            21.40           28.40              6.42                45.98
# 6            23.90           33.65              7.76                48.83
# 7            24.58           38.60              9.60                50.18
# 8              NaN             NaN               NaN                  NaN
# 9              NaN             NaN               NaN                  NaN
# 10             NaN             NaN               NaN                  NaN
# 11             NaN             NaN               NaN                  NaN

# %%
df
# Out:
#       date  cpi_away_food  med_inc_house  avg_chipotle  avg_cava  \
# 0   1/1/18        275.893        77700.0         14.07     17.31
# 1   1/1/19        284.410        83260.0         14.96     18.73
# 2   1/1/20        293.944        81580.0         17.75     20.52
# 3   1/1/21        307.296        81270.0         18.90     20.97
# 4   1/1/22        330.822        79500.0         20.00     20.77
# 5   1/1/23        354.256        82690.0         20.54     20.54
# 6   1/1/24        368.743        83730.0         20.94     21.32
# 7   1/1/25        382.378        85157.0         21.13     21.71
# 8      NaN            NaN            NaN           NaN       NaN
# 9      NaN            NaN            NaN           NaN       NaN
# 10     NaN            NaN            NaN           NaN       NaN
# 11     NaN            NaN            NaN           NaN       NaN
#
#     avg_sweetgreen  cpi_zero_index  house_zero_index  chipotle_zero_index
# 0            14.39            0.00              0.00                 0.00
# 1            14.90            3.09              7.16                 6.33
# 2            17.95            6.54              4.99                26.15
# 3            19.23           11.38              4.59                34.33
# 4            19.89           19.91              2.32                42.15
# 5            21.40           28.40              6.42                45.98
# 6            23.90           33.65              7.76                48.83
# 7            24.58           38.60              9.60                50.18
# 8              NaN             NaN               NaN                  NaN
# 9              NaN             NaN               NaN                  NaN
# 10             NaN             NaN               NaN                  NaN
# 11             NaN             NaN               NaN                  NaN

# %%
df["cava_zero_index"] = df["avg_cava"].apply(lambda x:round((x-cava_start)/cava_start*100, 2))
df
# Out:
#       date  cpi_away_food  med_inc_house  avg_chipotle  avg_cava  \
# 0   1/1/18        275.893        77700.0         14.07     17.31
# 1   1/1/19        284.410        83260.0         14.96     18.73
# 2   1/1/20        293.944        81580.0         17.75     20.52
# 3   1/1/21        307.296        81270.0         18.90     20.97
# 4   1/1/22        330.822        79500.0         20.00     20.77
# 5   1/1/23        354.256        82690.0         20.54     20.54
# 6   1/1/24        368.743        83730.0         20.94     21.32
# 7   1/1/25        382.378        85157.0         21.13     21.71
# 8      NaN            NaN            NaN           NaN       NaN
# 9      NaN            NaN            NaN           NaN       NaN
# 10     NaN            NaN            NaN           NaN       NaN
# 11     NaN            NaN            NaN           NaN       NaN
#
#     avg_sweetgreen  cpi_zero_index  house_zero_index  chipotle_zero_index  \
# 0            14.39            0.00              0.00                 0.00
# 1            14.90            3.09              7.16                 6.33
# 2            17.95            6.54              4.99                26.15
# 3            19.23           11.38              4.59                34.33
# 4            19.89           19.91              2.32                42.15
# 5            21.40           28.40              6.42                45.98
# 6            23.90           33.65              7.76                48.83
# 7            24.58           38.60              9.60                50.18
# 8              NaN             NaN               NaN                  NaN
# 9              NaN             NaN               NaN                  NaN
# 10             NaN             NaN               NaN                  NaN
# 11             NaN             NaN               NaN                  NaN
#
#     cava_zero_index
# 0              0.00
# 1              8.20
# 2             18.54
# 3             21.14
# 4             19.99
# 5             18.66
# 6             23.17
# 7             25.42
# 8               NaN
# 9               NaN
# 10              NaN
# 11              NaN

# %%
df["sweetgreen_zero_index"] = df["avg_sweetgreen"].apply(lambda x:round((x-sweetgreen_start)/sweetgreen_start*100, 2))
df
# Out:
#       date  cpi_away_food  med_inc_house  avg_chipotle  avg_cava  \
# 0   1/1/18        275.893        77700.0         14.07     17.31
# 1   1/1/19        284.410        83260.0         14.96     18.73
# 2   1/1/20        293.944        81580.0         17.75     20.52
# 3   1/1/21        307.296        81270.0         18.90     20.97
# 4   1/1/22        330.822        79500.0         20.00     20.77
# 5   1/1/23        354.256        82690.0         20.54     20.54
# 6   1/1/24        368.743        83730.0         20.94     21.32
# 7   1/1/25        382.378        85157.0         21.13     21.71
# 8      NaN            NaN            NaN           NaN       NaN
# 9      NaN            NaN            NaN           NaN       NaN
# 10     NaN            NaN            NaN           NaN       NaN
# 11     NaN            NaN            NaN           NaN       NaN
#
#     avg_sweetgreen  cpi_zero_index  house_zero_index  chipotle_zero_index  \
# 0            14.39            0.00              0.00                 0.00
# 1            14.90            3.09              7.16                 6.33
# 2            17.95            6.54              4.99                26.15
# 3            19.23           11.38              4.59                34.33
# 4            19.89           19.91              2.32                42.15
# 5            21.40           28.40              6.42                45.98
# 6            23.90           33.65              7.76                48.83
# 7            24.58           38.60              9.60                50.18
# 8              NaN             NaN               NaN                  NaN
# 9              NaN             NaN               NaN                  NaN
# 10             NaN             NaN               NaN                  NaN
# 11             NaN             NaN               NaN                  NaN
#
#     cava_zero_index  sweetgreen_zero_index
# 0              0.00                   0.00
# 1              8.20                   3.54
# 2             18.54                  24.74
# 3             21.14                  33.63
# 4             19.99                  38.22
# 5             18.66                  48.71
# 6             23.17                  66.09
# 7             25.42                  70.81
# 8               NaN                    NaN
# 9               NaN                    NaN
# 10              NaN                    NaN
# 11              NaN                    NaN

# %%
df
# Out:
#       date  cpi_away_food  med_inc_house  avg_chipotle  avg_cava  \
# 0   1/1/18        275.893        77700.0         14.07     17.31
# 1   1/1/19        284.410        83260.0         14.96     18.73
# 2   1/1/20        293.944        81580.0         17.75     20.52
# 3   1/1/21        307.296        81270.0         18.90     20.97
# 4   1/1/22        330.822        79500.0         20.00     20.77
# 5   1/1/23        354.256        82690.0         20.54     20.54
# 6   1/1/24        368.743        83730.0         20.94     21.32
# 7   1/1/25        382.378        85157.0         21.13     21.71
# 8      NaN            NaN            NaN           NaN       NaN
# 9      NaN            NaN            NaN           NaN       NaN
# 10     NaN            NaN            NaN           NaN       NaN
# 11     NaN            NaN            NaN           NaN       NaN
#
#     avg_sweetgreen  cpi_zero_index  house_zero_index  chipotle_zero_index  \
# 0            14.39            0.00              0.00                 0.00
# 1            14.90            3.09              7.16                 6.33
# 2            17.95            6.54              4.99                26.15
# 3            19.23           11.38              4.59                34.33
# 4            19.89           19.91              2.32                42.15
# 5            21.40           28.40              6.42                45.98
# 6            23.90           33.65              7.76                48.83
# 7            24.58           38.60              9.60                50.18
# 8              NaN             NaN               NaN                  NaN
# 9              NaN             NaN               NaN                  NaN
# 10             NaN             NaN               NaN                  NaN
# 11             NaN             NaN               NaN                  NaN
#
#     cava_zero_index  sweetgreen_zero_index
# 0              0.00                   0.00
# 1              8.20                   3.54
# 2             18.54                  24.74
# 3             21.14                  33.63
# 4             19.99                  38.22
# 5             18.66                  48.71
# 6             23.17                  66.09
# 7             25.42                  70.81
# 8               NaN                    NaN
# 9               NaN                    NaN
# 10              NaN                    NaN
# 11              NaN                    NaN

# %%
df_clean = df.dropna()
df_clean
# Out:
#      date  cpi_away_food  med_inc_house  avg_chipotle  avg_cava  \
# 0  1/1/18        275.893        77700.0         14.07     17.31
# 1  1/1/19        284.410        83260.0         14.96     18.73
# 2  1/1/20        293.944        81580.0         17.75     20.52
# 3  1/1/21        307.296        81270.0         18.90     20.97
# 4  1/1/22        330.822        79500.0         20.00     20.77
# 5  1/1/23        354.256        82690.0         20.54     20.54
# 6  1/1/24        368.743        83730.0         20.94     21.32
# 7  1/1/25        382.378        85157.0         21.13     21.71
#
#    avg_sweetgreen  cpi_zero_index  house_zero_index  chipotle_zero_index  \
# 0           14.39            0.00              0.00                 0.00
# 1           14.90            3.09              7.16                 6.33
# 2           17.95            6.54              4.99                26.15
# 3           19.23           11.38              4.59                34.33
# 4           19.89           19.91              2.32                42.15
# 5           21.40           28.40              6.42                45.98
# 6           23.90           33.65              7.76                48.83
# 7           24.58           38.60              9.60                50.18
#
#    cava_zero_index  sweetgreen_zero_index
# 0             0.00                   0.00
# 1             8.20                   3.54
# 2            18.54                  24.74
# 3            21.14                  33.63
# 4            19.99                  38.22
# 5            18.66                  48.71
# 6            23.17                  66.09
# 7            25.42                  70.81

# %%
df_clean.to_csv('combined_analysis3.csv', index=False)
